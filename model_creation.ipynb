# %% [markdown]
# # Emotion Detection

# %% [markdown]
# ## importing Libraries

# %%
import matplotlib.pyplot as plt
from glob import glob
import cv2
import random
import os
# %matplotlib inline

from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import Dense, Input, Dropout, Flatten, Conv2D
from tensorflow.keras.layers import BatchNormalization, Activation, MaxPooling2D
from tensorflow.keras.models import Model,Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
from tensorflow.keras.utils import plot_model

from IPython.display import SVG, Image
import tensorflow as tf
print("Tensorflow version:", tf.__version__)
# Out:
# Tensorflow version: 2.9.1

# %%
# Exploring Dataset

# %%
images = glob("train/**/**")
for i in range(9):
    image = random.choice(images)
    plt.figure(figsize=(5,15))
    plt.subplot(331+i)
    plt.imshow(cv2.imread(image));plt.axis('off')
    plt.show()

# %%
## Preparing Data for Training

# %%
img_size = 48
batch_size =64
datagen_train = ImageDataGenerator()
train_generator = datagen_train.flow_from_directory("train/",
                                                    target_size = (img_size, img_size),
                                                    color_mode = "grayscale",
                                                    batch_size = batch_size,
                                                    class_mode = "categorical",
                                                    shuffle = True)
datagen_validation = ImageDataGenerator()
validation_generator = datagen_train.flow_from_directory("test/",
                                                    target_size = (img_size, img_size),
                                                    color_mode = "grayscale",
                                                    batch_size = batch_size,
                                                    class_mode = "categorical",
                                                    shuffle = True)
# Out:
# Found 28709 images belonging to 7 classes.
# Found 7178 images belonging to 7 classes.

# %% [markdown]
# ## Defining Model

# %%
def Convolution(input_tensor, filters, kernel_size):
    x = Conv2D(filters = filters, kernel_size = kernel_size, padding = "same")(input_tensor)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = MaxPooling2D(pool_size = (2,2))(x)
    x = Dropout(0.25)(x)

    return x

# %%
def Dense_f(input_tensor, nodes):
    x = Dense(nodes)(input_tensor)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = Dropout(0.25)(x)

    return x

# %%
def model_fer(input_shape):
    inputs = Input(input_shape)
    conv_1 = Convolution(inputs,32,(3,3))
    conv_2 = Convolution(inputs,64,(5,5))
    conv_3 = Convolution(inputs,128,(3,3))

    flatten = Flatten()(conv_3)

    dense_1 = Dense_f(flatten,256)

    output = Dense(7,activation = "softmax")(dense_1)
    model = Model(inputs = [inputs], outputs = [output])

    model.compile(loss = ['categorical_crossentropy'], optimizer = 'adam', metrics = ['accuracy'])

    return model

# %%
model = model_fer((48,48,1))
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 48, 48, 1)]       0
#
#  conv2d_2 (Conv2D)           (None, 48, 48, 128)       1280
#
#  batch_normalization_2 (Batc  (None, 48, 48, 128)      512
#  hNormalization)
#
#  activation_2 (Activation)   (None, 48, 48, 128)       0
#
#  max_pooling2d_2 (MaxPooling  (None, 24, 24, 128)      0
#  2D)
#
#  dropout_2 (Dropout)         (None, 24, 24, 128)       0
#
#  flatten (Flatten)           (None, 73728)             0
#
#  dense (Dense)               (None, 256)               18874624
#
#  batch_normalization_3 (Batc  (None, 256)              1024
#  hNormalization)
#
#  activation_3 (Activation)   (None, 256)               0
#
#  dropout_3 (Dropout)         (None, 256)               0
#
#  dense_1 (Dense)             (None, 7)                 1799
#
# =================================================================
# Total params: 18,879,239
# Trainable params: 18,878,471
# Non-trainable params: 768
# _________________________________________________________________

# %% [markdown]
# # initrializing the Model

# %%
epochs = 15
steps_per_epoch = train_generator.n//train_generator.batch_size
validation_steps = validation_generator.n//validation_generator.batch_size

checkpoint = ModelCheckpoint("model_weights.h5", monitor ='val_accuracy', save_weights_only = True, mode = 'max', verbose = 1)
callbacks = [checkpoint]

# %% [markdown]
# # Training the Model

# %% [markdown]
# ## The next cell takes time to complete

# %%
history = model.fit(
x = train_generator,
steps_per_epoch = steps_per_epoch,
epochs = epochs,
validation_data = validation_generator,
validation_steps = validation_steps,
callbacks = callbacks)
# Out:
# Epoch 1/15
# 448/448 [==============================] - ETA: 0s - loss: 1.6568 - accuracy: 0.3709
# Epoch 1: saving model to model_weights.h5
# 448/448 [==============================] - 409s 908ms/step - loss: 1.6568 - accuracy: 0.3709 - val_loss: 1.5796 - val_accuracy: 0.3817
# Epoch 2/15
# 448/448 [==============================] - ETA: 0s - loss: 1.3567 - accuracy: 0.4902
# Epoch 2: saving model to model_weights.h5
# 448/448 [==============================] - 201s 448ms/step - loss: 1.3567 - accuracy: 0.4902 - val_loss: 1.6239 - val_accuracy: 0.3544
# Epoch 3/15
# 448/448 [==============================] - ETA: 0s - loss: 1.1957 - accuracy: 0.5517
# Epoch 3: saving model to model_weights.h5
# 448/448 [==============================] - 199s 445ms/step - loss: 1.1957 - accuracy: 0.5517 - val_loss: 1.8619 - val_accuracy: 0.2761
# Epoch 4/15
# 448/448 [==============================] - ETA: 0s - loss: 1.0650 - accuracy: 0.6047
# Epoch 4: saving model to model_weights.h5
# 448/448 [==============================] - 205s 458ms/step - loss: 1.0650 - accuracy: 0.6047 - val_loss: 1.5678 - val_accuracy: 0.4033
# Epoch 5/15
# 448/448 [==============================] - ETA: 0s - loss: 0.9452 - accuracy: 0.6554
# Epoch 5: saving model to model_weights.h5
# 448/448 [==============================] - 198s 441ms/step - loss: 0.9452 - accuracy: 0.6554 - val_loss: 1.6995 - val_accuracy: 0.4022
# Epoch 6/15
# 448/448 [==============================] - ETA: 0s - loss: 0.8185 - accuracy: 0.7060
# Epoch 6: saving model to model_weights.h5
# 448/448 [==============================] - 196s 438ms/step - loss: 0.8185 - accuracy: 0.7060 - val_loss: 1.5796 - val_accuracy: 0.4389
# Epoch 7/15
# 448/448 [==============================] - ETA: 0s - loss: 0.7033 - accuracy: 0.7477
# Epoch 7: saving model to model_weights.h5
# 448/448 [==============================] - 209s 466ms/step - loss: 0.7033 - accuracy: 0.7477 - val_loss: 1.7610 - val_accuracy: 0.4194
# Epoch 8/15
# 448/448 [==============================] - ETA: 0s - loss: 0.5942 - accuracy: 0.7896
# Epoch 8: saving model to model_weights.h5
# 448/448 [==============================] - 198s 441ms/step - loss: 0.5942 - accuracy: 0.7896 - val_loss: 1.5419 - val_accuracy: 0.4845
# Epoch 9/15
# 448/448 [==============================] - ETA: 0s - loss: 0.5162 - accuracy: 0.8226
# Epoch 9: saving model to model_weights.h5
# 448/448 [==============================] - 197s 439ms/step - loss: 0.5162 - accuracy: 0.8226 - val_loss: 1.7999 - val_accuracy: 0.4616
# Epoch 10/15
# 448/448 [==============================] - ETA: 0s - loss: 0.4510 - accuracy: 0.8466
# Epoch 10: saving model to model_weights.h5
# 448/448 [==============================] - 194s 432ms/step - loss: 0.4510 - accuracy: 0.8466 - val_loss: 2.2863 - val_accuracy: 0.3668
# Epoch 11/15
# 448/448 [==============================] - ETA: 0s - loss: 0.3812 - accuracy: 0.8710
# Epoch 11: saving model to model_weights.h5
# 448/448 [==============================] - 194s 432ms/step - loss: 0.3812 - accuracy: 0.8710 - val_loss: 1.7275 - val_accuracy: 0.5004
# Epoch 12/15
# 448/448 [==============================] - ETA: 0s - loss: 0.3419 - accuracy: 0.8850
# Epoch 12: saving model to model_weights.h5
# 448/448 [==============================] - 273s 610ms/step - loss: 0.3419 - accuracy: 0.8850 - val_loss: 1.9791 - val_accuracy: 0.4628
# Epoch 13/15
# 448/448 [==============================] - ETA: 0s - loss: 0.3025 - accuracy: 0.8987
# Epoch 13: saving model to model_weights.h5
# 448/448 [==============================] - 200s 447ms/step - loss: 0.3025 - accuracy: 0.8987 - val_loss: 1.9038 - val_accuracy: 0.4894
# Epoch 14/15
# 448/448 [==============================] - ETA: 0s - loss: 0.2751 - accuracy: 0.9076
# Epoch 14: saving model to model_weights.h5
# 448/448 [==============================] - 195s 435ms/step - loss: 0.2751 - accuracy: 0.9076 - val_loss: 1.8983 - val_accuracy: 0.5036
# Epoch 15/15
# 448/448 [==============================] - ETA: 0s - loss: 0.2441 - accuracy: 0.9195
# Epoch 15: saving model to model_weights.h5
# 448/448 [==============================] - 194s 434ms/step - loss: 0.2441 - accuracy: 0.9195 - val_loss: 1.9186 - val_accuracy: 0.4856

# %% [markdown]
# ## Model Evaluation

# %%
model.evaluate(validation_generator)
# Out:
# 113/113 [==============================] - 12s 107ms/step - loss: 1.9188 - accuracy: 0.4857
# [1.9187911748886108, 0.48565059900283813]

# %% [markdown]
# ## Piotting Loss

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.legend(['Train','Validation'],loc = 'upper left')
plt.subplots_adjust(top = 0.6,bottom = 0.0, right= 0.5, left= 0.0, hspace= 0.25,wspace= 0.35)

# %% [markdown]
# ## Ploting Accuracy

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.legend(['Train','Validation'],loc = 'upper left')
plt.subplots_adjust(top = 0.5,bottom = 0.0, right= 0.5, left= 0.0, hspace= 0.25,wspace= 0.35)

# %% [markdown]
# ## Saving Model

# %%
model_json = model.to_json()
with open("model_a.json","w")as json_file:
    json_file.write(model_json)
